# %%
from bukalapaklib import get_scrape, get_token, clean_df
from datetime import date

timestr = date.today()

PAGE = 5
CATEGORY_ID = 3263

params = {
    "prambanan_override" : "true",
    "category_id" : CATEGORY_ID,
    "sort" : "bestselling",
    "limit" : 30,
    "facet" : "true",
    #"brand": "true"
}
df_scraper = get_scrape(params, get_token, page=PAGE)
df_file = clean_df(df_scraper,timestr)

df_file
# Out:
# WARNING:root:no column specs_brand
#     condition          created_at       id max_quantity  \
# 0        Baru 2021-11-18 15:33:56  4gt5qip   2147483647
# 1        Baru 2022-01-24 10:02:58  4h0iapm   2147483647
# 2        Baru 2022-01-18 01:40:15  4gzus61   2147483647
# 3        Baru 2022-04-19 04:18:48  4h7am6d   2147483647
# 4        Baru 2021-11-18 15:34:21  4gt5qtj   2147483647
# ..        ...                 ...      ...          ...
# 145      Baru 2021-07-16 09:12:19  4g482qj   2147483647
# 146      Baru 2021-08-06 09:42:20  4g8tbd1   2147483647
# 147      Baru 2021-02-22 04:33:08  4bxt9zp   2147483647
# 148      Baru 2022-01-24 10:03:00  4h0iaqa   2147483647
# 149      Baru 2021-03-23 04:52:47  4e3oqjs   2147483647
#
#      merchant_return_insurance  min_quantity  \
# 0                        False             1
# 1                        False             1
# 2                        False             1
# 3                        False             1
# ...

# %%
import psycopg2
from sqlalchemy import create_engine

# %%
# establish connections
conn_string = 'postgresql://boerhand:1232@34.128.95.217/Sandbox'

  
db = create_engine(conn_string)
conn = db.connect()
conn1 = psycopg2.connect(
  database="Sandbox",
  user='boerhand', 
  password='1232', 
  host='34.128.95.217', 
  port= '5432'
)

conn1.autocommit = True
cursor = conn1.cursor()

#sql = '''CREATE TABLE sandbox_kopi();'''

#cursor.execute(sql)

df_file.to_sql('sandbox_kopi', conn, if_exists= 'append')
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File ~/miniconda3/envs/scraping/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1799, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798     if not evt_handled:
# -> 1799         self.dialect.do_executemany(
#    1800             cursor, statement, parameters, context
#    1801         )
#    1802 elif not parameters and context.no_parameters:
#
# File ~/miniconda3/envs/scraping/lib/python3.10/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:953, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     952     xtras = self._psycopg2_extras()
# --> 953     context._psycopg2_fetched_rows = xtras.execute_values(
#     954         cursor,
#     955         statement,
#     956         parameters,
# ...
